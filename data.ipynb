# %%
from main import *
import matplotlib.pyplot as plt

# %%
train_csv = "./data/train.csv"
test_csv = "./data/test.csv"

import pandas as pd

train_data = pd.read_csv(train_csv)
test_data = pd.read_csv(test_csv)

# %%
for column in train_data.drop(columns = ["time"]).columns:
    plt.plot(train_data["time"], train_data[column])
    plt.title(column)
    plt.show()

# %%
import seaborn as sns

cov = train_data.corr()

plt.figure()
sns.heatmap(cov)
# Out:
# <Axes: >
